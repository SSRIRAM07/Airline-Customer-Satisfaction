# %% [markdown]
# # Importing packages

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Airline_customer_satisfaction.csv")

# %% [markdown]
# # Data Cleaning

# %%
df.head()
# Out:
#   satisfaction   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  Gate location  ...  Online support  Ease of Online booking  \
# 0               0              2  ...               2                       3
# ...

# %%
df.tail()
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 129875     satisfied  disloyal Customer   29  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 129875             1731             5                                  5
# 129876             2087             2                                  3
# 129877             2320             3                                  0
# 129878             2450             3                                  2
# 129879             4307             3                                  4
#
#         Food and drink  Gate location  ...  Online support  \
# ...

# %%
df.describe()
# Out:
#                  Age  Flight Distance   Seat comfort  \
# count  129880.000000    129880.000000  129880.000000
# mean       39.427957      1981.409055       2.838597
# std        15.119360      1027.115606       1.392983
# min         7.000000        50.000000       0.000000
# 25%        27.000000      1359.000000       2.000000
# 50%        40.000000      1925.000000       3.000000
# 75%        51.000000      2544.000000       4.000000
# max        85.000000      6951.000000       5.000000
#
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# count                      129880.000000   129880.000000  129880.000000
# mean                            2.990645        2.851994       2.990422
# std                             1.527224        1.443729       1.305970
# min                             0.000000        0.000000       0.000000
# 25%                             2.000000        2.000000       2.000000
# ...

# %%
df.isnull().sum()
# Out:
# satisfaction                           0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['satisfaction']= df['satisfaction'].map({'dissatisfied':0,'satisfied':1})

# %%
df.head()
# Out:
#    satisfaction   Customer Type  Age   Type of Travel     Class  \
# 0             1  Loyal Customer   65  Personal Travel       Eco
# 1             1  Loyal Customer   47  Personal Travel  Business
# 2             1  Loyal Customer   15  Personal Travel       Eco
# 3             1  Loyal Customer   60  Personal Travel       Eco
# 4             1  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  Gate location  ...  Online support  Ease of Online booking  \
# 0               0              2  ...               2                       3
# ...

# %%
df.tail()
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 129875             1  disloyal Customer   29  Personal Travel       Eco
# 129876             0  disloyal Customer   63  Personal Travel  Business
# 129877             0  disloyal Customer   69  Personal Travel       Eco
# 129878             0  disloyal Customer   66  Personal Travel       Eco
# 129879             0  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 129875             1731             5                                  5
# 129876             2087             2                                  3
# 129877             2320             3                                  0
# 129878             2450             3                                  2
# 129879             4307             3                                  4
#
#         Food and drink  Gate location  ...  Online support  \
# ...

# %%
df['Customer Type']= df['Customer Type'].map({'Loyal Customer':0,'disloyal Customer':1})

# %%
df.head()
# Out:
#    satisfaction  Customer Type  Age   Type of Travel     Class  \
# 0             1              0   65  Personal Travel       Eco
# 1             1              0   47  Personal Travel  Business
# 2             1              0   15  Personal Travel       Eco
# 3             1              0   60  Personal Travel       Eco
# 4             1              0   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  Gate location  ...  Online support  Ease of Online booking  \
# 0               0              2  ...               2                       3
# ...

# %%
df.tail()
# Out:
#         satisfaction  Customer Type  Age   Type of Travel     Class  \
# 129875             1              1   29  Personal Travel       Eco
# 129876             0              1   63  Personal Travel  Business
# 129877             0              1   69  Personal Travel       Eco
# 129878             0              1   66  Personal Travel       Eco
# 129879             0              1   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 129875             1731             5                                  5
# 129876             2087             2                                  3
# 129877             2320             3                                  0
# 129878             2450             3                                  2
# 129879             4307             3                                  4
#
#         Food and drink  Gate location  ...  Online support  \
# ...

# %%
df['Type of Travel']= df['Type of Travel'].map({'Personal Travel':1})

# %%
df.head()
# Out:
#    satisfaction  Customer Type  Age  Type of Travel     Class  \
# 0             1              0   65             1.0       Eco
# 1             1              0   47             1.0  Business
# 2             1              0   15             1.0       Eco
# 3             1              0   60             1.0       Eco
# 4             1              0   70             1.0       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  Gate location  ...  Online support  Ease of Online booking  \
# 0               0              2  ...               2                       3
# ...

# %%
df['Class']= df['Class'].map({'Eco':0,'Business':1,'Eco Plus':2})

# %%
df.head()
# Out:
#    satisfaction  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0             1              0   65             1.0      0              265
# 1             1              0   47             1.0      1             2464
# 2             1              0   15             1.0      0             2138
# 3             1              0   60             1.0      0              623
# 4             1              0   70             1.0      0              354
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             0                                  0               0
# 1             0                                  0               0
# 2             0                                  0               0
# 3             0                                  0               0
# 4             0                                  0               0
#
#    Gate location  ...  Online support  Ease of Online booking  \
# ...

# %% [markdown]
# # Data visualization

# %%
sns.set_context("poster",font_scale= .7)
plt.figure(figsize=(20, 6))
ax= df["satisfaction"].value_counts().plot(kind="bar",color="crimson",rot=0)
for p in ax.patches:
    ax.annotate(int(p.get_height()),(p.get_x()+0.25,p.get_height()-100),
                ha="center",va="bottom",color="white")
ax.set_xticklabels(["Satisfied","Dissatified"],rotation=0)
plt.show()

# %%
sns.set_context("poster", font_scale=0.7)
plt.figure(figsize=(20, 6))

# Getting the value counts for the 'satisfaction' column
satisfaction_counts = df["satisfaction"].value_counts()

# Labels for the pie chart
labels = ["Satisfied", "Dissatisfied"]

# Colors for the pie chart
colors = ["crimson", "grey"]

# Exploding the pie slices (adjust the values as needed)
explode = [0.1, 0]  # This will "explode" each slice by 10%

# Plotting the pie chart
wedges, texts, autotexts = plt.pie(
    satisfaction_counts,
    labels=labels,
    colors=colors,
    explode=explode,
    autopct=lambda pct: int(round(pct * satisfaction_counts.sum() / 100)),
    startangle=90,
    counterclock=False,
    textprops={'color':"white", 'fontsize':12}
)

# Adjusting the size of the labels inside the pie chart
for text in autotexts:
    text.set_fontsize(12)

# Setting aspect ratio to be equal to ensure the pie is drawn as a circle
plt.axis('equal')

plt.show()

# %% [markdown]
# # Model building

# %%
# Importing necessary libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
#removing the unwanted columns
df=df.drop(columns="Type of Travel")

# %%
df=df.drop(columns="Arrival Delay in Minutes")

# %%
#split the dataset
X=df.drop(columns="satisfaction")
y=df["satisfaction"]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Customer Type                      129880 non-null  int64
#  1   Age                                129880 non-null  int64
#  2   Class                              129880 non-null  int64
#  3   Flight Distance                    129880 non-null  int64
#  4   Seat comfort                       129880 non-null  int64
#  5   Departure/Arrival time convenient  129880 non-null  int64
#  6   Food and drink                     129880 non-null  int64
#  7   Gate location                      129880 non-null  int64
#  8   Inflight wifi service              129880 non-null  int64
#  9   Inflight entertainment             129880 non-null  int64
#  10  Online support                     129880 non-null  int64
# ...

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 129880 entries, 0 to 129879
# Series name: satisfaction
# Non-Null Count   Dtype
# --------------   -----
# 129880 non-null  int64
# dtypes: int64(1)
# memory usage: 1014.8 KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import category_encoders as ce

# %%
encoder = ce.LeaveOneOutEncoder()
x=encoder.fit_transform(X,y)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Customer Type                      129880 non-null  int64
#  1   Age                                129880 non-null  int64
#  2   Class                              129880 non-null  int64
#  3   Flight Distance                    129880 non-null  int64
#  4   Seat comfort                       129880 non-null  int64
#  5   Departure/Arrival time convenient  129880 non-null  int64
#  6   Food and drink                     129880 non-null  int64
#  7   Gate location                      129880 non-null  int64
#  8   Inflight wifi service              129880 non-null  int64
#  9   Inflight entertainment             129880 non-null  int64
#  10  Online support                     129880 non-null  int64
# ...

# %% [markdown]
# # Train Test Spliting

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=40)

# %%
# Decision Tree
decision_tree = DecisionTreeClassifier()

# Random Forest
random_forest = RandomForestClassifier()

# K-Nearest Neighbors
knn = KNeighborsClassifier()

# Support Vector Machine
svc = SVC()

# %%
models=[decision_tree,random_forest,knn,svc]

# %% [markdown]
# # Accuracy of a model

# %%
for model in models:
    model_name = model.__class__.__name__
    print(f"Fitting model: {model_name}")
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{model_name} accuracy: {accuracy}")
# Out:
# Fitting model: DecisionTreeClassifier
# DecisionTreeClassifier accuracy: 0.9290113951339698
# Fitting model: RandomForestClassifier
# RandomForestClassifier accuracy: 0.9540729904527256
# Fitting model: KNeighborsClassifier
# KNeighborsClassifier accuracy: 0.7231290421927934
# Fitting model: SVC
# SVC accuracy: 0.611179550354173
